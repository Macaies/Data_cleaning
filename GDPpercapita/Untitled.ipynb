# %%
import pandas as pd

# %%
excel_file = r"C:\Users\rayma\OneDrive\Drive2\OneDrive\Desktop\GITHUB PORTFOLIO\DATA CLEAN\GDPpercapita\GDPpercapita.xlsx"

xls = pd.ExcelFile(excel_file)
print(xls.sheet_names)
# Out:
# ['Data', 'About', 'Footnotes', 'Settings', 'v']

# %%
percapitaGDP = pd.read_excel(excel_file,             
                            sheet_name= "Data",
                            skiprows = 0,
                            skipfooter = 1,
                            usecols = "A,C:W")

percapitaGDP.head()
# Out:
#   Income per person (fixed 2000 US$)         1961        1962        1963  \
# 0                           Abkhazia          NaN         NaN         NaN
# 1                        Afghanistan          NaN         NaN         NaN
# 2              Akrotiri and Dhekelia          NaN         NaN         NaN
# 3                            Albania          NaN         NaN         NaN
# 4                            Algeria  1085.414612  855.947986  1128.41578
#
#           1964         1965         1966         1967         1968  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4  1170.323896  1215.015783  1127.614288  1200.558225  1291.863983
#
#           1969  ...         1972         1973        1974         1975  \
# ...

# %%
percapitaGDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Income per person (fixed 2000 US$)  274 non-null    object
#  1   1961                                97 non-null     float64
#  2   1962                                97 non-null     float64
#  3   1963                                97 non-null     float64
#  4   1964                                97 non-null     float64
#  5   1965                                103 non-null    float64
#  6   1966                                105 non-null    float64
#  7   1967                                106 non-null    float64
#  8   1968                                107 non-null    float64
#  9   1969                                107 non-null    float64
#  10  1970                                119 non-null    float64
# ...

# %%
percapitaGDP.shape
# Out:
# (274, 22)
